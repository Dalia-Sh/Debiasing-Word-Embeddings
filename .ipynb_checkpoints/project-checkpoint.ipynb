# %%
import numpy as np
import pandas as pd
import json
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
import copy
import re

# %%
# Reading the embeddings file into a dictionary
# Every word will contain a 50-element vector
embeddings_index = dict()
with open('glove.6B.50d.txt',encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
# Reading the data files
with open('./data/definitional_pairs.json') as f:
    definitional_pairs = json.load(f)
    
with open('./data/equalize_pairs.json') as f:
    equalize_pairs = json.load(f)

with open('./data/gender_specific_seed.json') as f:
    gender_specific_words = json.load(f)
    
with open('./data/professions.json') as f:
        professions = json.load(f)
        profession_words = [p[0] for p in professions]
        visualization_professions = profession_words+ ["she", "he"]

# %% [markdown]
# Remomve the '_', so that the word for ex, vice_chancellor become vice-chancellor. I need the correct format to find it in glove

# %%
visualization_professions = [re.sub('_', "-", p) for p in visualization_professions]

# %% [markdown]
# Find professions in Glove embedding

# %%
# Selecting professions and she,he from glove 50 word embedding
professions_embedding = [(key,value) for (key,value) in embeddings_index.items() if key in visualization_professions]

# Saving in a CSV Dataframe for future use: 
professions_embedding_df = pd.DataFrame(professions_embedding)
#professions_embedding_df.to_csv(r'professions_embedding_df.csv')
a = (professions_embedding_df.iloc[:,1].values.tolist())
b = pd.DataFrame(a)
c = professions_embedding_df.iloc[:,0]
professions_embedding_df = pd.concat([c,b], axis=1)

# %% [markdown]
# ## Projecting Professions onto She-He Axis

# %% [markdown]
# STEP 1: Creating a list of functions needed

# %%
def squared (x):
    return(x**2)

# Normalizing function
def norm(df):
    t = df.apply(squared, axis=1)
    magnitude=np.array(np.sqrt(t.sum(axis=1)))
    for i in range(0,len(magnitude)):
        df.iloc[i,:] = df.iloc[i,:]/float(magnitude[i])
    return(df)

# Projection function: Projecting vec onto she_he
def projection(she_he,vec):
    myvec = np.array(vec)
    a = (np.sum(she_he*myvec))*she_he
    return(np.sqrt(np.sum([x**2 for x in a])))

# Cosine Similarity: df must be normalized using norm(df):
def cosine(she_he,vec):
    myvec = np.array(vec)
    return(np.dot(vec,she_he))

# %% [markdown]
# STEP 2: Normalize the vectors

# %%
# Embeddings Normalized:
embedd = professions_embedding_df.iloc[:,1:101]
norm_embedd = pd.concat([professions_embedding_df.iloc[:,0],norm(embedd)], axis=1)

# Professions Subset
professions_embedding = norm_embedd.iloc[2:len(norm_embedd),:]

# he vector
he = norm_embedd.iloc[0:1,:]

# He vector
she = norm_embedd.iloc[1:2,:]

# Extracting profession names:
professions_name = professions_embedding_df.iloc[2:299,0]

# %% [markdown]
# STEP 3: Projection of occupation onto She-He vector

# %%
# She Projection dataframe
she_emb = she.iloc[0,1:51]
she_projection = []
for i in (range(len(professions_embedding))):
    vec = professions_embedding.iloc[i,1:51]
    she_projection.append([cosine(she_emb, vec)])

she_projection_df = pd.DataFrame((she_projection),(professions_name), columns=['Projection_She'])
    
# He Projection dataframe
he_emb = he.iloc[0,1:51]
he_projection = []
for i in (range(len(professions_embedding))):
    vec = professions_embedding.iloc[i,1:51]
    he_projection.append([cosine(he_emb, vec)])
    
he_projection_df = pd.DataFrame((he_projection),(professions_name), columns=['Projection_He'])

# She-He projection dataframe
she_he_projection_df = pd.concat([she_projection_df,he_projection_df],axis=1)
she_he_projection_df["She-He"]=she_he_projection_df.iloc[:,0]-she_he_projection_df.iloc[:,1]

# %% [markdown]
# STEP 4: Listing the 15 most Extreme she Occupations:

# %%
print("Extreme she occupations:")
ex_she = list(she_he_projection_df.sort_values(by="She-He", ascending=False).head(15).index)
she_he_projection_df.sort_values(by="She-He", ascending=False).head(15)
# Out:
# Extreme she occupations:
#                Projection_She  Projection_He    She-He
# 0
# actress              0.622298       0.399250  0.223049
# ballerina            0.356527       0.139433  0.217094
# stylist              0.365576       0.159158  0.206418
# socialite            0.246396       0.045301  0.201094
# waitress             0.527643       0.328353  0.199290
# maid                 0.490526       0.304479  0.186047
# narrator             0.489649       0.315560  0.174090
# housewife            0.462341       0.291285  0.171056
# homemaker            0.393556       0.224252  0.169304
# receptionist         0.353116       0.184098  0.169018
# housekeeper          0.440772       0.273083  0.167689
# hairdresser          0.357484       0.191177  0.166306
# nurse                0.645697       0.480509  0.165188
# businesswoman        0.315136       0.151751  0.163385
# dancer               0.546302       0.389632  0.156671

# %% [markdown]
# STEP 4: Listing the 10 most Extreme he Occupations:

# %%
print("Extreme he occupations:")
ex_he = list(she_he_projection_df.sort_values(by="She-He", ascending=True).head(15).index)
she_he_projection_df.sort_values(by="She-He", ascending=True).head(15)
# Out:
# Extreme he occupations:
#                 Projection_She  Projection_He    She-He
# 0
# coach                 0.416748       0.603964 -0.187216
# caretaker             0.213615       0.384877 -0.171262
# captain               0.414357       0.582045 -0.167688
# manager               0.441148       0.602775 -0.161627
# colonel               0.288889       0.448114 -0.159225
# marshal               0.145598       0.301166 -0.155568
# midfielder            0.244918       0.399974 -0.155056
# skipper               0.186066       0.339630 -0.153563
# commander             0.283785       0.436572 -0.152787
# archbishop            0.172011       0.323747 -0.151736
# bishop                0.329106       0.480656 -0.151550
# footballer            0.259060       0.409027 -0.149967
# substitute            0.341734       0.488414 -0.146680
# lieutenant            0.338317       0.482009 -0.143692
# superintendent        0.235682       0.375934 -0.140253

# %%
# Putting it together in one dataframe:
she_he_projection_df['Professions'] = she_he_projection_df.axes[0].tolist()

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Visualization Top 30 Extreme Occupations from GloVe
#
# Project these 30 occupations on a 2d graph (she and he vectors) for visualization purposes.

# %%
# Creating a dataframe with top she embeddings
she_emb = she.iloc[0,1:51]
idx = she_he_projection_df.iloc[:,3].isin(ex_she)
she_prof = she_he_projection_df.loc[idx,:]

# Creating a dataframe with top he embeddings
he_emb = he.iloc[0,1:51]
idx = she_he_projection_df.iloc[:,3].isin(ex_he)
he_prof = she_he_projection_df.loc[idx,:]

# Concatenating dataframes:
extreme_she_he_df = pd.concat([she_prof,he_prof],axis=0)
extreme_she_he_df['Extreme She/He Occupations'] = np.repeat(["She","He"],15)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
ax = sns.scatterplot(x="Projection_He", y="Projection_She", hue="Extreme She/He Occupations",data=extreme_she_he_df)
for i in range(30):
    plt.text(extreme_she_he_df.iloc[i,1],extreme_she_he_df.iloc[i,0], extreme_she_he_df.iloc[i,3], bbox = dict(facecolor='grey', alpha =0.5))

# %% [markdown]
# ## Visualization Top 20 Extreme Occupations from W2Vec
# W2VecNEWS Extreme She-He Occupations (Based on Bolukbasi's paper)

# %%
# Subsetting She-He Occupations found in Bolukbasi's paper
w2vec_extreme_occupations = ['homemaker', 'nurse', 'receptionist', 'librarian', 'socialite', 'hairdresser', 'nanny', 'bookkeeper', 'stylist', 'housekeeper', 'maestro', 'skipper', 'protege', 'philosopher', 'captain', 'architect', 'financier', 'warrior', 'broadcaster', 'magician']
# Concatenating dataframes:
idx = she_he_projection_df.index.isin(w2vec_extreme_occupations)
extreme_she_he_projection_df = she_he_projection_df.loc[idx,:]
extreme_she_he_projection_df = extreme_she_he_projection_df.reindex(w2vec_extreme_occupations)
extreme_she_he_projection_df['Extreme She/He Occupations']= np.repeat(["She","He"],10)

# %%
# Visualizing
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
ax = sns.scatterplot(x="Projection_He", y="Projection_She", hue="Extreme She/He Occupations",data=extreme_she_he_projection_df)
for i in range(len(w2vec_extreme_occupations)):
    plt.text(extreme_she_he_projection_df.iloc[i,1],extreme_she_he_projection_df.iloc[i,0], extreme_she_he_projection_df.iloc[i,3], bbox = dict(facecolor='grey', alpha =0.5))

# %% [markdown]
# ## Debiasing Algorithm

# %%
# This function will take the definitional pairs and calculate the gender subspace
# embedding is the embedding we read
# We assume dimension k = 10
def get_gender_subspace(pairs, embedding, num_components=10):
    matrix = []
    for a, b in pairs:
        # if a pair in definitional_pairs is not in the embedding, then skip it
        # otherwise:
        if (a in embedding and b in embedding):
            # get the mean of the 2 vectors
            center = (embedding[a] + embedding[b])/2 # D_i = 2
            # then get the deviations of the mean from a and from b
            # add these to a matrix
            matrix.append(embedding[a] - center)
            matrix.append(embedding[b] - center)
    # eg if we take 18 pairs, we will get 36 entries
    # and a 36x50 matrix for the 18 pairs
    matrix = np.array(matrix)
    pca = PCA(n_components = num_components)
    pca.fit(matrix)
    # return 10 vectors where each element will be a 50-dimension vector
    return pca.components_

# %%
# Normalizing each word in the embedding
def normalize(embedding):
    for word in embedding:
        embedding[word] /= np.linalg.norm(embedding[word])

# Get projection on subspace of the word u
def get_projection_on_subspace(subspace, u):
    temp = subspace.dot(u)
    # Expanding dimension from (10,) to (10,1)
    temp = np.expand_dims(temp, -1)
    # Return a 50-dimensional vector
    return np.sum(temp * subspace, axis=0)

# %%
def debias_new(embedding, gender_specific_words, definitional_pairs, equalize_pairs):
    # Taking a copy of the embedding so that the real embedding is not changed
    result_embedding = copy.deepcopy(embedding)
    normalize(result_embedding)
    
    # calculate gender subspace
    gender_subspace = get_gender_subspace(definitional_pairs, result_embedding)
    projections = dict()
    
    # projections
    specific_set = set(gender_specific_words)
    for w in embedding:
        # getting projection of w onto the subspace (for each word)
        projection_gender_subspace = get_projection_on_subspace(gender_subspace, result_embedding[w])
        # Adding to projection dictionary
        projections[w] = projection_gender_subspace
        # Remove the gender bias (Neutralizing process)
        # If w is not in set of gender specific words,
        # we subtract the gender bias (projection_gender_subspace)
        if w not in specific_set:           
            result_embedding[w] -= projection_gender_subspace
    normalize(result_embedding)
    
    # making all the words in equalize_pairs lowercase if they are in the embedding
    candidate_pairs = [(a.lower(), b.lower()) for (a, b) in equalize_pairs if a in result_embedding and b in result_embedding]
    
    # Equalizing process
    for (a, b) in candidate_pairs:
        mean = (result_embedding[a] + result_embedding[b]) / 2
        # Get the projection of mean onto the gender subspace
        mean_projection = get_projection_on_subspace(gender_subspace, mean)
        v = mean - mean_projection
        gender_factor_a = (projections[a] - mean_projection) / np.linalg.norm(projections[a] - mean_projection)
        result_embedding[a] = v + np.sqrt(1 - np.linalg.norm(v)**2) * gender_factor_a
        gender_factor_b = (projections[b] - mean_projection) / np.linalg.norm(projections[b] - mean_projection)
        result_embedding[b] = v + np.sqrt(1 - np.linalg.norm(v)**2) * gender_factor_b
            
    normalize(result_embedding)
    
    return result_embedding

# %%
result_embeddings = debias_new(embeddings_index, gender_specific_words, definitional_pairs, equalize_pairs)

# %% [markdown]
# ### A demonstration that the equalizing has successfully been performed

# %%
candidate_pairs = [(a.lower(), b.lower()) for (a, b) in equalize_pairs if a in result_embeddings and b in result_embeddings]
for profession in profession_words:
    profession = profession.lower()
    if profession in result_embeddings:
        for (a, b) in candidate_pairs:
            orig_male_distance = cosine_similarity(embeddings_index[a].reshape(1, -1), 
                                                   embeddings_index[profession].reshape(1, -1))[0, 0]
            orig_female_distance = cosine_similarity(embeddings_index[b].reshape(1, -1), 
                                                     embeddings_index[profession].reshape(1, -1))[0, 0]
            
            debiased_male_distance = cosine_similarity(result_embeddings[a].reshape(1, -1), 
                                                       result_embeddings[profession].reshape(1, -1))[0, 0]
            debiased_female_distance = cosine_similarity(result_embeddings[b].reshape(1, -1), 
                                                         result_embeddings[profession].reshape(1, -1))[0, 0]
            print('Profession: ' + profession)
            print('Original: Distance of {}: {}, Distance of {}: {}'.format(a, orig_male_distance, b, orig_female_distance))
            print('Debiased: Distance of {}: {}, Distance of {}: {}'.format(a, debiased_male_distance, b,
                                                                            debiased_female_distance))
# Out:
# Profession: accountant
# Original: Distance of monastery: 0.07968442142009735, Distance of convent: 0.20946644246578217
# Debiased: Distance of monastery: 0.21010078489780426, Distance of convent: 0.21010088920593262
# Profession: accountant
# Original: Distance of spokesman: 0.16799549758434296, Distance of spokeswoman: 0.21838490664958954
# Debiased: Distance of spokesman: 0.1686752438545227, Distance of spokeswoman: 0.1686752438545227
# Profession: accountant
# Original: Distance of councilman: 0.2092466801404953, Distance of councilwoman: 0.07784803956747055
# Debiased: Distance of councilman: 0.04404810443520546, Distance of councilwoman: 0.044048044830560684
# Profession: accountant
# Original: Distance of grandpa: 0.1392306238412857, Distance of grandma: 0.1299542933702469
# Debiased: Distance of grandpa: 0.1003631129860878, Distance of grandma: 0.1003630980849266
# Profession: accountant
# ...

# %%
len(equalize_pairs)
# Out:
# 52

# %% [markdown]
# ## Projecting Debiased Embeddings onto the She-He Vector

# %% [markdown]
# STEP 1: Find professions in the DEBIASED GloVe embedding

# %%
# Selecting professions and she,he from debiased glove 50 word embedding
professions_debias_embedding = [(key,value) for (key,value) in result_embeddings.items() if key in visualization_professions]

# %%
# Preprocessing to have a dataframe format:
professions_debias_embedding_df = pd.DataFrame(professions_debias_embedding)
a = (professions_debias_embedding_df.iloc[:,1].values.tolist())
b = pd.DataFrame(a)
c = professions_debias_embedding_df.iloc[:,0]
professions_debias_embedding_df = pd.concat([c,b], axis=1)
professions_embedding_df = professions_debias_embedding_df

# %% [markdown]
# STEP 2: I normalize the vectors

# %%
# Embeddings Normalized:
embedd = professions_embedding_df.iloc[:,1:101]
norm_embedd = pd.concat([professions_embedding_df.iloc[:,0],norm(embedd)], axis=1)

# Professions Subset
professions_embedding = norm_embedd.iloc[2:len(norm_embedd),:]

# he vector
he = norm_embedd.iloc[0:1,:]

# He vector
she = norm_embedd.iloc[1:2,:]

# Extracting profession names:
professions_name = professions_embedding_df.iloc[2:299,0]

# %% [markdown]
# STEP 3: Projection of occupation onto She-He vector

# %%
# She Projection dataframe
she_emb = she.iloc[0,1:51]
she_projection = []
for i in (range(len(professions_embedding))):
    vec = professions_embedding.iloc[i,1:51]
    she_projection.append([cosine(she_emb, vec)])

she_projection_df = pd.DataFrame((she_projection),(professions_name), columns=['Projection_She'])
    
# He Projection dataframe
he_emb = he.iloc[0,1:51]
he_projection = []
for i in (range(len(professions_embedding))):
    vec = professions_embedding.iloc[i,1:51]
    he_projection.append([cosine(he_emb, vec)])
    
he_projection_df = pd.DataFrame((he_projection),(professions_name), columns=['Projection_He'])

# She-He projection dataframe
she_he_projection_df = pd.concat([she_projection_df,he_projection_df],axis=1)

# %% [markdown]
# ## Visualization Top 20 Extreme Occupations from W2Vec

# %%
#W2vec Extreme Occupations: 
w2vec_extreme_occupations = ['homemaker', 'nurse', 'receptionist', 'librarian', 'socialite', 'hairdresser', 'nanny', 'bookkeeper', 'stylist', 'housekeeper', 'maestro', 'skipper', 'protege', 'philosopher', 'captain', 'architect', 'financier', 'warrior', 'broadcaster', 'magician']
# Concatenating dataframes:
idx = she_he_projection_df.index.isin(w2vec_extreme_occupations)
extreme_she_he_projection_df = she_he_projection_df.loc[idx,:]
extreme_she_he_projection_df = extreme_she_he_projection_df.reindex(w2vec_extreme_occupations)
extreme_she_he_projection_df['Extreme She/He Occupations']= np.repeat(["She","He"],10)
extreme_she_he_projection_df['Professions'] = extreme_she_he_projection_df.axes[0].tolist()

# %%
# Visualization
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
ax = sns.scatterplot(x="Projection_He", y="Projection_She", hue="Extreme She/He Occupations",data=extreme_she_he_projection_df)
for i in range(len(w2vec_extreme_occupations)):
    plt.text(extreme_she_he_projection_df.iloc[i,1],extreme_she_he_projection_df.iloc[i,0], extreme_she_he_projection_df.iloc[i,3], bbox = dict(facecolor='grey', alpha =0.5))

# %% [markdown]
# ## Visualization Top 30 Extreme Occupations from GloVe

# %%
# Creating a dataframe with top she embeddings
she_emb = she.iloc[0,1:51]
idx = she_he_projection_df.index.isin(ex_she)
she_prof = she_he_projection_df.loc[idx,:]

# Creating a dataframe with top he embeddings
he_emb = he.iloc[0,1:51]
idx = she_he_projection_df.index.isin(ex_he)
he_prof = she_he_projection_df.loc[idx,:]

# Concatenating dataframes:
extreme_she_he_df = pd.concat([she_prof,he_prof],axis=0)
extreme_she_he_df['Extreme She/He Occupations'] = np.repeat(["She","He"],15)
extreme_she_he_df['Professions'] = extreme_she_he_df.axes[0].tolist()

# %%
# Visualization
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
ax = sns.scatterplot(x="Projection_He", y="Projection_She", hue="Extreme She/He Occupations",data=extreme_she_he_df)
for i in range(len(w2vec_extreme_occupations)):
    plt.text(extreme_she_he_df.iloc[i,1],extreme_she_he_df.iloc[i,0], extreme_she_he_df.iloc[i,3], bbox = dict(facecolor='grey', alpha =0.5))

# %% [markdown]
# ## EXTRA (just experimenting): Finding top 20 most extreme occupations after debiasing

# %%
she_he_projection_df["She-He"]=she_he_projection_df.iloc[:,0]-she_he_projection_df.iloc[:,1]

print("Extreme she occupations:")
ex_she = list(she_he_projection_df.sort_values(by="She-He", ascending=False).head(15).index)
she_he_projection_df.sort_values(by="She-He", ascending=False).head(15)
# Out:
# Extreme she occupations:
#                Projection_She  Projection_He        She-He
# 0
# businesswoman        0.578686      -0.077633  6.563189e-01
# actress              0.623460       0.088195  5.352655e-01
# ballerina            0.488651      -0.032324  5.209745e-01
# waitress             0.543026       0.064776  4.782504e-01
# maid                 0.522641       0.076172  4.464687e-01
# housewife            0.527880       0.117384  4.104952e-01
# nun                  0.484181       0.192703  2.914784e-01
# handyman             0.159447      -0.012754  1.722016e-01
# salesman             0.275430       0.239296  3.613367e-02
# lifeguard            0.012044       0.012044  1.505246e-07
# skipper              0.157276       0.157276  1.273127e-07
# ranger               0.052881       0.052880  1.225582e-07
# fireman              0.241297       0.241297  1.153666e-07
# foreman              0.201104       0.201104  7.948934e-08
# ...

# %%
print("Extreme he occupations:")
ex_he = list(she_he_projection_df.sort_values(by="She-He", ascending=True).head(15).index)
she_he_projection_df.sort_values(by="She-He", ascending=True).head(15)
# Out:
# Extreme he occupations:
#                    Projection_She  Projection_He        She-He
# 0
# businessman             -0.077633       0.578686 -6.563190e-01
# dad                      0.098887       0.722883 -6.239963e-01
# councilman              -0.374307       0.230603 -6.049109e-01
# congressman             -0.174940       0.398461 -5.734013e-01
# statesman                0.061321       0.121427 -6.010548e-02
# monk                     0.228069       0.244696 -1.662738e-02
# mathematician            0.318288       0.318288 -2.804566e-07
# solicitor-general       -0.084696      -0.084696 -1.967353e-07
# architect                0.184253       0.184253 -1.874454e-07
# jurist                   0.196542       0.196542 -1.865214e-07
# vice-chancellor          0.292889       0.292889 -1.796846e-07
# politician               0.443512       0.443513 -1.738909e-07
# geologist                0.128965       0.128966 -1.609676e-07
# ...
