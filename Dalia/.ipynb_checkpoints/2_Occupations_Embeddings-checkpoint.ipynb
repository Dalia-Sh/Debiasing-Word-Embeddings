# %% [markdown]
# # Importing Professions

# %% [raw]
# # Preprocessing using R
# setwd("/Users/daliashanshal/DS8008-project/data")
# library(rjson)
# professionsJSON = fromJSON(file="professions.json")
# myprofessions = unlist(professionsJSON)
# idx = seq(1,length(myprofessions), by=3)
# myprofessions = myprofessions[idx]
# myprofessions = c(myprofessions, "she", "he")
# myprofessions = as.data.frame(myprofessions)
# write.csv(myprofessions, file="myprofessions.csv")

# %%
import pandas as pd
import os
os.getcwd()
data = pd.read_csv("/Users/daliashanshal/DS8008-project/Dalia/myprofessions.csv", encoding="latin1")
data.tail(13)
# 320 professions. 
# I added she, he at the end for embedding and pojection purposes.
# Out:
#      Unnamed: 0    myprofessions
# 309         310  vice_chancellor
# 310         311        violinist
# 311         312         vocalist
# 312         313           waiter
# 313         314         waitress
# 314         315           warden
# 315         316          warrior
# 316         317           welder
# 317         318           worker
# 318         319         wrestler
# 319         320           writer
# 320         321              she
# 321         322               he

# %%
# I only select the professions column I want to use
myprofessions = data.iloc[:,1]
professions = myprofessions.values.tolist()

# %%
#I want to remomve the '_', so that the word for ex, vice_chancellor
# become vice-chancellor. I need the correct format to find it in glove
import re
professions = [re.sub('_', "-", p) for p in professions]

# %%
# from numpy import array
# from numpy import asarray
# from numpy import zeros
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences

# # Prepare tokenizer
# t = Tokenizer()
# t.fit_on_texts(professions)

# # Set vocab size
# vocab_size = len(t.word_index)+1

# # integer encode the professions
# encoded_professions = t.texts_to_sequences(professions)

# %%
# load the whole embedding into memory
from numpy import array
from numpy import asarray
embeddings_index = dict()
#first download the glove word emedding and then search for them
f = open('/Users/daliashanshal/Desktop/NLP_Project/glove.6B.50d.txt',encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
# Selecting professions and she,he from glove 50d word embedding
professions_embedding = [(key,value) for (key,value) in embeddings_index.items() if key in professions]

# %%
# Note for self: the original occupation list is 320 occup. In glove, we detected 299-2(he,she)
# of those.
len(professions_embedding)
# Out:
# 299

# %%
# She minus he bias vector
she_minus_he = professions_embedding[1][1] - professions_embedding[0][1]

# %%
# Saving professions embeddings to csv (for R manipulation)
professions_embedding_df = pd.DataFrame(professions_embedding)
professions_embedding_df.to_csv(r'professions_embedding_df.csv')

# %%
# Draft and tests
import numpy as np
print(np.sqrt(sum((she_minus_he)**2)))
# Normalize vectors first
#professions_embedding_df
# Out:
# 2.6675397755987453
#                    0                                                  1
# 0                 he  [-0.20092, -0.060271, -0.61766, -0.8444, 0.578...
# 1                she  [0.060382, 0.37821, -0.75142, -0.72159, 0.5864...
# 2          president  [-0.11875, 0.6722, 0.19444, 0.55269, 0.53698, ...
# 3           minister  [0.039931, 0.50725, -0.18625, 0.32268, 0.65427...
# 4           director  [-0.17574, 0.36446, -0.78658, 0.68581, 0.15354...
# 5          secretary  [-0.14508, 0.14645, -0.76128, 0.38553, 0.74353...
# 6              coach  [-1.3191, 0.50071, -0.44091, 0.27854, -0.28167...
# 7            manager  [-0.1344, 0.26481, -0.29072, 0.92514, 0.57527,...
# 8              judge  [-0.41753, -0.77215, -0.77358, 0.10329, 1.0391...
# 9            officer  [0.048403, -0.60703, 0.19108, 0.18007, 1.2004,...
# 10            deputy  [-0.55629, 0.18394, -0.10779, 0.76178, 1.0457,...
# 11          attorney  [-0.37196, -0.50656, -0.46389, 0.89191, 0.6054...
# 12         professor  [-1.271, 1.0787, -1.12, -0.36538, 0.32833, 0.0...
# 13           student  [-1.0729, 0.94103, 0.084904, -1.0766, 0.42866,...
# 14            lawyer  [-0.48076, -0.024485, -0.56514, 0.56811, 1.029...
# 15         character  [0.19475, 0.60994, -0.6662, 0.01851, 1.3729, 1...
# 16           captain  [-0.11905, -0.41267, -0.66755, -0.31787, 0.928...
# 17           analyst  [-0.34903, 0.75611, 0.68763, 1.1225, 0.75698, ...
# 18         commander  [0.55243, -0.46295, 0.55669, 0.073398, 1.4797,...
# 19            writer  [-1.21, 1.37, -0.47428, 0.11, 0.19885, 0.04632...
# 20            author  [-0.50246, 1.2178, -0.80065, -0.45854, 0.65779...
# 21            editor  [-1.352, 0.82277, -0.093772, 0.28771, 0.50169,...
# 22        ambassador  [0.00079396, 0.99118, -0.52747, 0.23156, 0.954...
# 23             actor  [-0.66174, 1.02, -0.17757, -0.31617, 0.6497, 1...
# 24            doctor  [0.66999, 0.11698, -0.46322, -0.90012, 0.5656,...
# 25            artist  [-0.91093, 0.99808, -0.71439, -0.23005, 0.6083...
# 26           senator  [-0.39334, 0.18748, 0.6471, 0.14527, 0.15966, ...
# 27            singer  [-1.0509, 0.82552, -0.62979, 0.1709, 0.18777, ...
# 28      commissioner  [-0.73737, -0.17652, -1.1406, 0.41187, -0.333,...
# 29           soldier  [-0.05888, -0.11433, 0.09146, -0.77894, 1.9506...
# ..               ...                                                ...
# 265          janitor  [-0.26025, -0.36283, -0.017778, -1.1583, 0.820...
# 266        homemaker  [-0.58787, 0.42075, -0.4811, -0.53404, 0.71332...
# 267      neurologist  [0.37849, 0.14899, -0.65082, -1.1121, 0.43005,...
# 268       serviceman  [-0.22091, -0.46931, 0.42961, -0.38241, 1.3515...
# 269      hairdresser  [-0.50159, 0.15289, -0.72516, -0.51014, 0.6108...
# 270           pundit  [-1.1049, 0.15223, -0.014464, -0.059963, -0.58...
# 271     restaurateur  [-0.18474, 0.22442, -0.49089, 0.038111, 0.0891...
# 272       understudy  [-0.18632, 0.0042058, -0.46909, -0.95784, -0.0...
# 273        lifeguard  [-0.54616, -0.16709, -0.62639, 0.090629, -0.55...
# 274          trucker  [-0.88727, -0.36692, -0.14989, -0.83457, -0.13...
# 275          jeweler  [0.063371, 0.17001, -0.44866, 0.35392, 1.0973,...
# 276           hitman  [0.54367, -0.60795, 0.35447, -0.74881, 0.27929...
# 277  photojournalist  [-0.88783, 0.069353, 0.18629, -0.17948, 0.5447...
# 278         marksman  [-0.96843, -0.079027, 0.27753, -0.43086, 0.768...
# 279     neurosurgeon  [0.12738, -0.27544, -0.66757, -0.34829, 0.3689...
# 280    dermatologist  [0.23991, 0.044289, -0.75032, -0.74273, 0.0449...
# 281          crooner  [-0.72017, 0.4095, -0.13465, -0.093504, -0.825...
# 282       ballplayer  [-1.0985, 0.50381, -0.70214, -0.36131, 0.78279...
# 283       bookkeeper  [-0.34434, -0.6107, -0.15938, -0.61911, 0.4500...
# 284    valedictorian  [-1.5156, 1.15, -0.39481, -1.6196, 0.25093, -0...
# 285           welder  [-0.72635, 0.067496, 0.18645, -0.35383, 0.0667...
# 286          realtor  [-0.20773, -0.049532, -0.10941, 0.15801, 0.343...
# 287        paralegal  [-0.5322, -0.10126, -0.74378, -0.37041, 0.2845...
# 288      radiologist  [0.31352, -0.44593, -0.18577, -0.44922, 0.7353...
# 289      parishioner  [0.50185, 0.98924, -0.3041, -1.423, 1.4226, 0....
# 290        patrolman  [-1.0208, -0.43023, 0.45392, -0.56515, -0.1932...
# 291          artiste  [-0.5846, 0.10701, -0.8437, -0.46919, -0.15898...
# 292           cabbie  [0.065895, -0.17732, 0.15649, -0.9394, 0.45226...
# 293        cabdriver  [-0.17549, -0.25544, -0.23225, -0.72502, 0.489...
# 294       softspoken  [-0.94889, -0.33918, -0.29025, 0.15159, 0.7110...
#
# [295 rows x 2 columns]
